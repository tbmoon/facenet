# %%
import os
import glob
import pandas as pd
import time
from PIL import Image

# %%
verbosity     = 1
which_dataset = 4

# %%
if   which_dataset == 0:
    root_dir = "/run/media/hoosiki/WareHouse2/home/mtb/datasets/vggface2/train_mtcnnpy_182"
elif which_dataset == 1:
    root_dir = "/run/media/hoosiki/WareHouse2/home/mtb/datasets/vggface2/test_mtcnnpy_182"
elif which_dataset == 2:
    root_dir = "/run/media/hoosiki/WareHouse2/home/mtb/datasets/lfw/lfw_mtcnnpy_182"
elif which_dataset == 3:
    root_dir = "facescrub/train/"
elif which_dataset == 4:
    root_dir = "facescrub/valid/"
else:
    root_dir = "/run/media/hoosiki/WareHouse2/home/mtb/datasets/my_pictures/my_pictures_mtcnnpy_182"

# %%
files = glob.glob(root_dir+"/*/*")
len(files)
# Out:
# 2930

# %%
time0 = time.time()
df = pd.DataFrame()
print("The number of files: ", len(files))
for idx, file in enumerate(files):
    if idx%1000 == 0:
        print("[{}/{}]".format(idx, len(files)-1))
    '''    
    try:
        img = Image.open(file) # open the image file
        img.verify() # verify that it is, in fact, an image
    except (IOError, SyntaxError) as e:
        if verbosity == 1:
            print('Bad file:', file) # print out the names of corrupt files
        pass
    else:
        face_id    = os.path.basename(file).split('.')[0]
        face_label = os.path.basename(os.path.dirname(file))
        df = df.append({'id': face_id, 'name': face_label}, ignore_index = True)
    '''    
    extension = file.split('.')[-1]
    face_id    = os.path.basename(file).split('.')[0]
    face_label = os.path.basename(os.path.dirname(file))
    df = df.append({'id': face_id, 'name': face_label, 'ext': extension}, ignore_index = True)
# Out:
# The number of files:  2930
# [0/2929]
# [1000/2929]
# [2000/2929]

# %%
df = df.sort_values(by = ['name', 'id']).reset_index(drop = True)

# %%
df['class'] = pd.factorize(df['name'])[0]

# %%
if which_dataset == 0:
    df.to_csv("train_vggface2.csv", index = False)
elif which_dataset == 1:
    df.to_csv("test_vggface2.csv", index = False)
elif which_dataset == 2:
    df.to_csv("valid_lfw.csv", index = False)
elif which_dataset == 3:
    df.to_csv("train_facescrub.csv", index = False)
elif which_dataset == 4:
    df.to_csv("valid_facescrub.csv", index = False)
else:
    df.to_csv("my_pictures.csv", index = False)

elapsed_time = time.time() - time0
print("elapsted time: ", elapsed_time//3600, "h", elapsed_time%3600//60, "m")
# Out:
# elapsted time:  0.0 h 0.0 m

# %%
df
# Out:
#       ext    id                name  class
# 0     jpg     1       Aaron Eckhart      0
# 1     jpg   102       Aaron Eckhart      0
# 2     jpg   118       Aaron Eckhart      0
# 3     jpg   130       Aaron Eckhart      0
# 4     jpg   141       Aaron Eckhart      0
# 5     jpg   148       Aaron Eckhart      0
# 6     jpg   159       Aaron Eckhart      0
# 7     jpg   163       Aaron Eckhart      0
# 8     jpg   168       Aaron Eckhart      0
# 9     jpg   186       Aaron Eckhart      0
# 10    jpg   198       Aaron Eckhart      0
# 11    jpg    20       Aaron Eckhart      0
# 12    jpg   200       Aaron Eckhart      0
# 13    jpg   202       Aaron Eckhart      0
# 14    jpg   209       Aaron Eckhart      0
# 15    jpg   210       Aaron Eckhart      0
# 16    jpg   211       Aaron Eckhart      0
# 17    jpg   216       Aaron Eckhart      0
# 18    jpg   217       Aaron Eckhart      0
# 19    jpg   219       Aaron Eckhart      0
# 20    jpg   222       Aaron Eckhart      0
# 21    jpg   225       Aaron Eckhart      0
# 22    jpg   232       Aaron Eckhart      0
# 23    jpg    24       Aaron Eckhart      0
# 24    jpg    27       Aaron Eckhart      0
# 25    jpg     4       Aaron Eckhart      0
# 26    jpg    49       Aaron Eckhart      0
# 27    jpg     5       Aaron Eckhart      0
# 28    jpg    50       Aaron Eckhart      0
# 29    jpg    58       Aaron Eckhart      0
# ...   ...   ...                 ...    ...
# 2900  jpg  6771  Valerie Bertinelli     96
# 2901  jpg  8166      Yasmine Bleeth     97
# 2902  jpg  8181      Yasmine Bleeth     97
# 2903  jpg  8187      Yasmine Bleeth     97
# 2904  jpg  8208      Yasmine Bleeth     97
# 2905  jpg  8210      Yasmine Bleeth     97
# 2906  jpg  8212      Yasmine Bleeth     97
# 2907  jpg  8218      Yasmine Bleeth     97
# 2908  jpg  8228      Yasmine Bleeth     97
# 2909  jpg  8234      Yasmine Bleeth     97
# 2910  jpg  8239      Yasmine Bleeth     97
# 2911  jpg  8241      Yasmine Bleeth     97
# 2912  jpg  8243      Yasmine Bleeth     97
# 2913  jpg  8258      Yasmine Bleeth     97
# 2914  JPG  8261      Yasmine Bleeth     97
# 2915  jpg  8262      Yasmine Bleeth     97
# 2916  jpg  8280      Yasmine Bleeth     97
# 2917  jpg  8281      Yasmine Bleeth     97
# 2918  jpg  8287      Yasmine Bleeth     97
# 2919  jpg  8294      Yasmine Bleeth     97
# 2920  jpg  8328      Yasmine Bleeth     97
# 2921  jpg  8338      Yasmine Bleeth     97
# 2922  jpg  8339      Yasmine Bleeth     97
# 2923  jpg  8342      Yasmine Bleeth     97
# 2924  jpg  8356      Yasmine Bleeth     97
# 2925  jpg  8358      Yasmine Bleeth     97
# 2926  JPG  8366      Yasmine Bleeth     97
# 2927  jpg  8370      Yasmine Bleeth     97
# 2928  jpg  8371      Yasmine Bleeth     97
# 2929  jpg  8378      Yasmine Bleeth     97
#
# [2930 rows x 4 columns]
